# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyasingh581/historical_data-EDA/blob/main/Copy_of_Historical_Trader_Data_from_Hyperliquid11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
#
# ##### Team -Kavya singh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project involved an extensive Exploratory Data Analysis (EDA) of historical cryptocurrency trading data from a platform. The primary objective was to gain actionable insights into trading patterns, user behavior, and platform performance to enhance business objectives related to trading optimization, user experience, and profitability.
#
# Key steps included data loading, initial data inspection, handling of missing and duplicate values, and crucial data wrangling processes such as converting timestamp columns to datetime objects and extracting time-based features. Variables were described, and their unique values were examined to understand their distributions and potential for analysis.
#
# Through various visualizations and correlation analyses, we uncovered significant insights:
# *   **Dynamic Trading Volumes**: Identified peak daily and hourly trading activities, crucial for resource allocation and operational efficiency.
# *   **Coin Performance Discrepancies**: Revealed varying profitability across different cryptocurrencies, suggesting opportunities for targeted strategies and risk management.
# *   **Fee Structure Analysis**: Explored the distribution of transaction fees and its relationship with trade size, providing a foundation for optimizing the platform's fee model.
# *   **High-Value Account Identification**: Pinpointed the most active and profitable users, emphasizing the importance of dedicated client relationship management.
# *   **Risk and Profitability Profiles**: Examined the distribution of 'Closed PnL' and its correlation with 'Start Position' and 'Trade Side', highlighting areas for enhanced risk management tools and user education.
#
# Based on these findings, a comprehensive set of solutions was proposed to the business, focusing on optimizing resource allocation, enhancing profitability through coin-specific strategies, refining fee structures, strategically engaging high-value accounts, improving risk management and user education, and diversifying market offerings. This EDA provides a robust, data-driven foundation for strategic decision-making to drive sustainable growth and profitability in the dynamic cryptocurrency market.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/kavyasingh581

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The primary problem addressed by this project is the need for a comprehensive understanding of historical cryptocurrency trading data to identify patterns, evaluate platform performance, and gain actionable insights. Specifically, the business aims to:
#
# *   **Optimize Trading Performance**: Understand which cryptocurrencies are most profitable, when trading activity peaks, and how transaction fees impact overall profitability.
# *   **Enhance User Experience**: Identify key user behaviors, understand the distribution of profits and losses, and recognize the impact of different trade parameters on user outcomes.
# *   **Improve Platform Profitability**: Develop data-driven strategies for resource allocation, fee structure optimization, and targeted client engagement to drive sustainable growth and revenue.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objectives for this project are to:
#
# *   **Optimize Trading Performance**: By understanding cryptocurrency profitability, peak trading times, and fee impacts, the platform aims to improve overall trading efficiency and outcomes.
# *   **Enhance User Experience**: Through insights into user behavior, profit/loss distributions, and trade parameters, the goal is to create a more supportive and beneficial trading environment for users.
# *   **Improve Platform Profitability**: By developing data-driven strategies for resource allocation, optimizing fee structures, and engaging high-value clients, the business seeks to drive sustainable growth and increase revenue.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/historical_data.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
df.head()
# Out:
#                                       Account  Coin  Execution Price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    Size Tokens  Size USD Side     Timestamp IST  Start Position Direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    Closed PnL                                   Transaction Hash     Order ID  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (211224, 16)

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  object
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()
# Out:
# Account             0
# Coin                0
# Execution Price     0
# Size Tokens         0
# Size USD            0
# Side                0
# Timestamp IST       0
# Start Position      0
# Direction           0
# Closed PnL          0
# Transaction Hash    0
# Order ID            0
# Crossed             0
# Fee                 0
# Trade ID            0
# Timestamp           0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ### What I know about the dataset:
#
# *   **Dimensions**: The dataset contains `211,224` rows and `16` columns.
# *   **Data Types**: The columns consist of a mix of data types:
#     *   `object` (likely strings): `Account`, `Coin`, `Side`, `Timestamp IST`, `Direction`, `Transaction Hash`.
#     *   `float64`: `Execution Price`, `Size Tokens`, `Size USD`, `Start Position`, `Closed PnL`, `Fee`, `Trade ID`, `Timestamp`.
#     *   `int64`: `Order ID`.
#     *   `bool`: `Crossed`.
# *   **Missing Values**: There are **no missing values** in any of the columns, which is excellent for analysis.
# *   **Duplicate Values**: There are **no duplicate rows** in the dataset.
# *   **First Few Rows**: The `df.head()` output shows details of cryptocurrency trades, including account IDs, coin types, execution prices, trade sizes in tokens and USD, trade side (BUY/SELL), timestamps, position details, profit/loss, transaction hashes, order IDs, and fees.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns
# Out:
# Index(['Account', 'Coin', 'Execution Price', 'Size Tokens', 'Size USD', 'Side',
#        'Timestamp IST', 'Start Position', 'Direction', 'Closed PnL',
#        'Transaction Hash', 'Order ID', 'Crossed', 'Fee', 'Trade ID',
#        'Timestamp'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Execution Price   Size Tokens      Size USD  Start Position  \
# count    211224.000000  2.112240e+05  2.112240e+05    2.112240e+05
# mean      11414.723350  4.623365e+03  5.639451e+03   -2.994625e+04
# std       29447.654868  1.042729e+05  3.657514e+04    6.738074e+05
# min           0.000005  8.740000e-07  0.000000e+00   -1.433463e+07
# 25%           4.854700  2.940000e+00  1.937900e+02   -3.762311e+02
# 50%          18.280000  3.200000e+01  5.970450e+02    8.472793e+01
# 75%         101.580000  1.879025e+02  2.058960e+03    9.337278e+03
# max      109004.000000  1.582244e+07  3.921431e+06    3.050948e+07
#
#           Closed PnL      Order ID            Fee      Trade ID     Timestamp
# count  211224.000000  2.112240e+05  211224.000000  2.112240e+05  2.112240e+05
# mean       48.749001  6.965388e+10       1.163967  5.628549e+14  1.737744e+12
# std       919.164828  1.835753e+10       6.758854  3.257565e+14  8.689920e+09
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# *   **Account**: An alphanumeric ID representing a unique user account. This is likely an identifier for the traders or entities involved in the transactions.
# *   **Coin**: The cryptocurrency being traded (e.g., '@107'). This is a categorical variable indicating the asset.
# *   **Execution Price**: The price at which the trade was executed. This is a numerical (float) variable.
# *   **Size Tokens**: The quantity of the cryptocurrency tokens involved in the trade. This is a numerical (float) variable.
# *   **Size USD**: The value of the trade in US Dollars. This is a numerical (float) variable.
# *   **Side**: Indicates whether the trade was a 'BUY' or a 'SELL'. This is a categorical variable.
# *   **Timestamp IST**: The exact date and time when the trade occurred, provided in IST (Indian Standard Time). This is an object type, which will likely need conversion to a datetime format for time-series analysis.
# *   **Start Position**: The position size of the account at the start of the trade. This is a numerical (float) variable, potentially indicating the trader's existing holdings or exposure.
# *   **Direction**: The direction of the trade, either 'Buy' or 'Sell'. This is a categorical variable, which appears to be redundant with 'Side' but might contain nuances.
# *   **Closed PnL**: The realized Profit and Loss from the trade. This is a numerical (float) variable, indicating the financial outcome of the transaction.
# *   **Transaction Hash**: A unique identifier for the blockchain transaction. This is an alphanumeric string (object type).
# *   **Order ID**: A unique identifier for the specific trade order. This is an integer variable.
# *   **Crossed**: A boolean variable (True/False) that might indicate if the order crossed the spread or was executed at a specific price point.
# *   **Fee**: The transaction fee incurred for the trade. This is a numerical (float) variable.
# *   **Trade ID**: A unique identifier for the trade. This is a numerical (float) variable, which might need to be treated as a categorical or identifier type if unique.
# *   **Timestamp**: Another timestamp variable, currently a float. This will likely need conversion to a datetime format and its relationship with 'Timestamp IST' should be investigated.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
df.nunique()
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  Account is 32 .
# No. of unique values in  Coin is 246 .
# No. of unique values in  Execution Price is 60162 .
# No. of unique values in  Size Tokens is 59304 .
# No. of unique values in  Size USD is 118493 .
# No. of unique values in  Side is 2 .
# No. of unique values in  Timestamp IST is 27977 .
# No. of unique values in  Start Position is 196923 .
# No. of unique values in  Direction is 12 .
# No. of unique values in  Closed PnL is 90720 .
# No. of unique values in  Transaction Hash is 101184 .
# No. of unique values in  Order ID is 50555 .
# No. of unique values in  Crossed is 2 .
# No. of unique values in  Fee is 138802 .
# No. of unique values in  Trade ID is 2810 .
# No. of unique values in  Timestamp is 7 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df['Timestamp IST'] = pd.to_datetime(df['Timestamp IST'], format='%d-%m-%Y %H:%M')
# Convert 'Timestamp' to datetime, assuming it's a Unix timestamp in milliseconds
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='ms')

# Check the unique values in 'Direction' column
print("Unique values in 'Direction' column before cleaning:", df['Direction'].unique())

# Standardize 'Direction' column to 'Buy' or 'Sell'
# Assuming any value containing 'Buy' is 'Buy' and 'Sell' is 'Sell', and others might be cleaned or investigated.
df['Direction'] = df['Direction'].apply(lambda x: 'Buy' if 'Buy' in x else ('Sell' if 'Sell' in x else x))

# Check the unique values in 'Direction' column after cleaning
print("Unique values in 'Direction' column after cleaning:", df['Direction'].unique())
# Out:
# Unique values in 'Direction' column before cleaning: ['Buy' 'Sell' 'Open Long' 'Close Long' 'Spot Dust Conversion' 'Open Short'
#  'Close Short' 'Long > Short' 'Short > Long' 'Auto-Deleveraging'
#  'Liquidated Isolated Short' 'Settlement']
# Unique values in 'Direction' column after cleaning: ['Buy' 'Sell' 'Open Long' 'Close Long' 'Spot Dust Conversion' 'Open Short'
#  'Close Short' 'Long > Short' 'Short > Long' 'Auto-Deleveraging'
#  'Liquidated Isolated Short' 'Settlement']

# %%
# Display info to verify data type changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
#  14  Trade ID          211224 non-null  float64
# ...

# %%
# Extract time-based features from 'Timestamp IST'
df['Year'] = df['Timestamp IST'].dt.year
df['Month'] = df['Timestamp IST'].dt.month
df['Day'] = df['Timestamp IST'].dt.day
df['DayOfWeek'] = df['Timestamp IST'].dt.dayofweek
df['Hour'] = df['Timestamp IST'].dt.hour

# %%
# Convert 'Trade ID' to object type if it's an identifier
df['Trade ID'] = df['Trade ID'].astype(object)

# %%
print("\nDataFrame after extracting time features and converting Trade ID type:")
df.info()
# Out:
# DataFrame after extracting time features and converting Trade ID type:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Account           211224 non-null  object
#  1   Coin              211224 non-null  object
#  2   Execution Price   211224 non-null  float64
#  3   Size Tokens       211224 non-null  float64
#  4   Size USD          211224 non-null  float64
#  5   Side              211224 non-null  object
#  6   Timestamp IST     211224 non-null  datetime64[ns]
#  7   Start Position    211224 non-null  float64
#  8   Direction         211224 non-null  object
#  9   Closed PnL        211224 non-null  float64
#  10  Transaction Hash  211224 non-null  object
#  11  Order ID          211224 non-null  int64
#  12  Crossed           211224 non-null  bool
#  13  Fee               211224 non-null  float64
# ...

# %%
df['Direction'].value_counts()
# Out:
# Direction
# Open Long                    49895
# Close Long                   48678
# Open Short                   39741
# Close Short                  36013
# Sell                         19902
# Buy                          16716
# Spot Dust Conversion           142
# Short > Long                    70
# Long > Short                    57
# Auto-Deleveraging                8
# Liquidated Isolated Short        1
# Settlement                       1
# Name: count, dtype: int64

# %%
# Verify the consistency between 'Side' and 'Direction'
# They both appear to be 'Buy' or 'Sell', let's check for any discrepancies.
print("\nAre 'Side' and 'Direction' consistent?")
print(df[df['Side'].str.lower() != df['Direction'].str.lower()].empty)
# Out:
# Are 'Side' and 'Direction' consistent?
# False

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Here's a summary of the data manipulations I've performed and the insights gathered from the wrangling process:
#
# ### Manipulations Done:
#
# 1.  **Timestamp Conversion**: The `Timestamp IST` column has been successfully converted from an object type to a `datetime64[ns]` format, using the specified `'%d-%m-%Y %H:%M'` format. The `Timestamp` column, initially a float, has also been converted to `datetime64[ns]` by interpreting its values as Unix milliseconds, resolving the `OutOfBoundsDatetime` error from the previous attempt.
# 2.  **Direction Column Standardisation (Partial)**: An attempt was made to standardize the `Direction` column to simply 'Buy' or 'Sell'. However, as observed from the unique values *after* cleaning, the logic applied (`lambda x: 'Buy' if 'Buy' in x else ('Sell' if 'Sell' in x else x)`) only changed values that explicitly contained 'Buy' or 'Sell'. This means more specific trade directions like 'Open Long', 'Close Long', 'Open Short', 'Close Short', etc., are still present. This indicates that the `Direction` column provides more granular information than a simple 'Buy' or 'Sell'.
# 3.  **Time-Based Feature Extraction**: New columns (`Year`, `Month`, `Day`, `DayOfWeek`, `Hour`) have been successfully extracted from the `Timestamp IST` column. These new features will be valuable for analyzing temporal patterns in the trading data.
# 4.  **Trade ID Type Conversion**: The `Trade ID` column, which was a float, has been converted to an `object` type, acknowledging its role as a unique identifier rather than a numerical value for calculation.
#
# ### Insights Found:
#
# *   **Data Type Readiness**: The key timestamp columns are now correctly formatted as datetime objects, enabling proper time-series analysis.
# *   **Direction vs. Side Inconsistency**: The check for consistency between `Side` and `Direction` returned `False`, confirming that these two columns are not entirely redundant. The `Direction` column retains more detailed information about the nature of the trade (e.g., whether it's opening or closing a position) beyond just a simple 'Buy' or 'Sell', which is captured by the `Side` column. This granularity in `Direction` could be important for deeper analysis of trading strategies.
# *   **New Temporal Dimensions**: The extracted time-based features provide new dimensions to explore the dataset, such as trade volume by hour, day of the week, or month, which can reveal trading patterns or market behavior over time.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Aggregate 'Size USD' by day to get daily trading volume
daily_volume = df.groupby(df['Timestamp IST'].dt.date)['Size USD'].sum().reset_index()
daily_volume.columns = ['Date', 'Daily Trading Volume USD']

plt.figure(figsize=(15, 7))
sns.lineplot(data=daily_volume, x='Date', y='Daily Trading Volume USD', marker='o')
plt.title('Daily Trading Volume (Size USD) Over Time')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume (USD)')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I selected a line plot to visualize 'Daily Trading Volume (Size USD) Over Time' because it is the most effective chart type for displaying trends and patterns in time-series data. By aggregating the 'Size USD' on a daily basis and plotting it against the date, we can clearly observe fluctuations, growth, or decline in trading activity over the recorded period.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# *   **Trading Activity Trends**: The chart reveals how the total trading volume in USD changes from day to day. We can identify periods of high trading activity (peaks) and low activity (troughs).
# *   **Potential Anomalies**: Sudden spikes or drops in volume might indicate specific market events, news releases, or influential trades that occurred on those particular days.
# *   **Overall Trend**: Depending on the time range, an overall upward or downward trend in trading volume might be visible, suggesting growing or diminishing interest in the traded cryptocurrencies on this platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, the insights from this chart can significantly impact business positively:
#
# *   **Resource Allocation**: High trading volume days might require more system resources, customer support, or liquidity provisions. Understanding these patterns allows the business to proactively allocate resources, preventing bottlenecks and improving user experience.
# *   **Marketing and Strategy**: Identifying periods of increased activity can help tailor marketing campaigns or launch new features during optimal times to maximize engagement.
# *   **Risk Management**: Unusual spikes in volume could signal market volatility, prompting a review of risk parameters or increasing monitoring efforts.
# *   **Informing Trading Products**: Understanding when and why trading volume increases for certain assets can help in developing more relevant trading products or services.
#
# Insights that could lead to negative growth would depend on the interpretation and actions taken. For example, a sustained decline in daily trading volume without clear external reasons could indicate a loss of user interest or competitiveness, which would necessitate strategic changes to prevent negative growth. Failing to act on insights about increasing risk during high-volume periods could also lead to significant losses.

# %% [markdown]
# Chart - 2

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Execution Price'], bins=50, kde=True)
plt.title('Distribution of Execution Price')
plt.xlabel('Execution Price')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# A histogram was chosen to visualize the distribution of 'Execution Price' because it effectively displays the frequency of different price ranges. By showing the shape of the data, we can quickly identify where most trades are concentrated, if the distribution is skewed, or if there are multiple peaks (modes) in the pricing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# *   **Price Concentration**: The histogram will show the most frequent execution price ranges. This helps in understanding the typical price at which assets are traded.
# *   **Skewness and Outliers**: We can observe if the distribution is skewed (e.g., more trades at lower prices than higher prices) or if there are extreme outliers, indicating trades at unusually high or low prices.
# *   **Market Dynamics**: The shape of the distribution might reflect market volatility or the presence of different pricing strategies employed by traders.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, the insights from the 'Execution Price' distribution can have a positive business impact:
#
# *   **Pricing Strategy and Optimization**: Understanding common price ranges can help in optimizing order book depth, setting appropriate bid-ask spreads, and designing pricing algorithms.
# *   **Risk Management**: Identifying unusual price concentrations or outliers can highlight potential market manipulation, system glitches, or significant market events that need investigation, thereby improving risk mitigation strategies.
# *   **Product Development**: If certain price points are consistently popular, it might suggest opportunities for new trading products or features tailored to those price levels.
#
# Insights that could lead to negative growth would typically arise from ignoring unusual patterns. For instance, if the histogram reveals a high frequency of trades at very low prices (potentially indicating a 'dump' or flash crash) and the platform doesn't have mechanisms to manage such volatility, it could lead to significant user losses and reputational damage.

# %% [markdown]
# #### Chart - 3

# %%
avg_pnl_by_coin = df.groupby('Coin')['Closed PnL'].mean().sort_values(ascending=False).reset_index()

plt.figure(figsize=(20, 10)) # Adjusted figure size for better readability
sns.barplot(data=avg_pnl_by_coin, x='Coin', y='Closed PnL', hue='Coin', palette='viridis', legend=False)
plt.title('Average Closed PnL per Coin')
plt.xlabel('Coin')
plt.ylabel('Average Closed PnL')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I chose a bar chart to visualize the 'Average Closed PnL per Coin' because it is highly effective for comparing a quantitative variable ('Average Closed PnL') across distinct categorical groups ('Coin'). The bars allow for easy comparison of profitability across different cryptocurrencies, and sorting them helps quickly identify the top and bottom performers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# *   **Most/Least Profitable Coins**: The chart will immediately reveal which coins have the highest average positive PnL and which ones lead to the largest average losses. This indicates the inherent profitability (or lack thereof) of trading specific assets on this platform.
# *   **Performance Discrepancies**: Significant differences in average PnL across coins could point to varying market conditions, liquidity, or trading strategies associated with each asset.
# *   **Focus Areas**: Coins with particularly high average PnL might be opportunities for further investigation into successful strategies, while coins with consistently negative PnL might warrant a review of risk or trading approaches.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Absolutely, these insights can drive significant positive business impact:
#
# *   **Optimized Trading Strategies**: Traders (and the platform if providing insights) can adjust their focus towards coins that historically yield higher average profits and potentially reduce exposure to consistently losing assets. This directly improves overall profitability.
# *   **Product Development & Marketing**: The platform can highlight and promote coins with strong positive PnL to attract more traders, or develop educational content around trading strategies for those coins.
# *   **Risk Management**: Identifying coins with significant average losses can trigger warnings or require stricter risk parameters, preventing large losses for traders and maintaining platform stability.
# *   **Market Research**: Understanding why certain coins are more profitable than others can provide valuable market intelligence, helping to predict future trends or identify undervalued/overvalued assets.
#
# Insights that could lead to negative growth would arise from *ignoring* these findings. For example, if the chart clearly shows that a highly promoted coin consistently leads to losses for users, and the platform fails to address this (e.g., by providing better tools, warnings, or adjusting fees), it could lead to user dissatisfaction, churn, and damage to the platform's reputation. Similarly, if the platform does not manage the risks associated with highly volatile but profitable coins, it could lead to significant individual losses during market downturns, impacting overall user trust and potentially business growth.

# %% [markdown]
# #### Chart - 4

# %%
hourly_volume = df.groupby('Hour')['Size USD'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Hour', y='Size USD', data=hourly_volume, hue='Hour', palette='viridis', legend=False)
plt.title('Total Trading Volume (Size USD) by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Total Trading Volume (USD)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a bar plot to visualize the 'Total Trading Volume (Size USD) by Hour of Day' because it effectively compares a quantitative variable (trading volume) across discrete categorical groups (hours of the day). This type of chart clearly highlights periods of high and low activity, making it easy to identify peak trading hours and understand the daily rhythm of the market.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **Peak Trading Hours**: The chart will clearly show at which hours the trading volume is highest. This indicates when the platform experiences the most activity and when users are most engaged.
# *   **Low Activity Periods**: Conversely, it will also highlight hours with minimal trading, which could be useful for scheduling maintenance or identifying times when market liquidity might be lower.
# *   **User Behavior Patterns**: This gives insight into the typical trading habits of users, such as whether they prefer to trade during working hours, evenings, or late at night/early morning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can drive significant positive business impact:
#
# *   **Resource Management**: Knowing peak hours allows the platform to optimize server capacity and allocate technical resources more efficiently, ensuring smooth operations during high-traffic periods and reducing costs during low-traffic times.
# *   **Customer Support Staffing**: Support teams can be staffed more strategically to align with peak trading hours, improving response times and user satisfaction.
# *   **Targeted Marketing and Promotions**: Promotional campaigns, new feature announcements, or educational content can be scheduled to go live during peak engagement hours to maximize reach and impact.
# *   **Market Monitoring and Risk Management**: Enhanced monitoring can be deployed during peak volatility hours (which often correlate with high volume) to detect unusual activity or potential market manipulation faster.
#
# Insights that could lead to negative growth would arise from *ignoring* these patterns. For instance, failing to scale infrastructure during peak hours could lead to system outages, frustrated users, and a loss of trust. Similarly, not recognizing periods of low liquidity during off-peak hours could expose the platform or its users to higher risks if large trades are executed without sufficient market depth.

# %% [markdown]
# #### Chart - 5

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Closed PnL'], bins=100, kde=True)
plt.title('Distribution of Closed PnL')
plt.xlabel('Closed PnL')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen to visualize the distribution of 'Closed PnL' because it effectively displays the frequency of different profit and loss ranges. By showing the shape of the data, we can identify common profit or loss amounts, as well as the presence of extreme gains or losses.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **Common PnL Ranges**: The histogram will highlight the most frequent profit or loss values, indicating typical trade outcomes.
# *   **Skewness and Outliers**: We can observe if the distribution is skewed (e.g., more small losses and a few large gains, or vice versa) or if there are significant outliers representing unusually high profits or losses.
# *   **Risk Profile**: The spread and shape of the distribution can give an indication of the overall risk profile of the trading activity on the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, insights from the 'Closed PnL' distribution can have a significant positive business impact:
#
# *   **Performance Evaluation**: Understanding the typical PnL outcomes helps in evaluating the overall performance of traders and trading strategies. This can inform educational content or tools for users.
# *   **Risk Management**: Identifying the frequency of large losses can prompt a review of risk parameters, margin requirements, or stop-loss mechanisms to protect users and the platform. Conversely, frequent small losses might indicate a need for better trading education.
# *   **Platform Feature Development**: If a high number of trades result in small profits, the platform might focus on features that help scale up profitable strategies. If there are many large losses, features to mitigate risk could be prioritized.
# *   **Attracting Traders**: Highlighting the potential for profit (if the distribution shows a positive trend) can be a marketing tool, while demonstrating a commitment to minimizing losses through robust risk management can build trust.
#
# Insights that could lead to negative growth typically arise from *ignoring* adverse patterns. For example, if the distribution shows a high frequency of large losses without adequate risk mitigation strategies, users might lose confidence in the platform, leading to churn. Also, if the platform fails to identify and address systemic issues leading to negative PnL for a significant portion of its users, it could face regulatory scrutiny or reputational damage.

# %% [markdown]
# #### Chart - 6

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Fee'], bins=100, kde=True)
plt.title('Distribution of Transaction Fees')
plt.xlabel('Fee Amount')
plt.ylabel('Frequency')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a histogram to visualize the 'Distribution of Transaction Fees' because it effectively displays the frequency of different fee amounts. This helps in understanding the typical costs associated with trades and identifying any patterns or unusual fee structures.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **Fee Concentration**: The histogram will show the most frequent fee ranges, indicating the typical cost of a transaction.
# *   **Skewness and Outliers**: We can observe if the distribution is skewed (e.g., many small fees and a few large ones) or if there are extreme outliers, which might correspond to very large trades or specific fee structures.
# *   **Cost Structure Insights**: This helps in understanding the overall cost landscape for users and the revenue generation mechanism for the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, insights from the 'Distribution of Transaction Fees' can have a positive business impact:
#
# *   **Revenue Optimization**: Understanding the distribution of fees can help the platform optimize its fee structure to maximize revenue while remaining competitive.
# *   **User Satisfaction**: Identifying common fee amounts can help in setting transparent fee policies, which improves user trust and satisfaction.
# *   **Detecting Anomalies**: Unusual spikes or concentrations in fee amounts might indicate system errors, fraudulent activity, or unexpected user behavior that needs investigation.
# *   **Product Development**: Insights might suggest opportunities for different fee tiers, subscription models, or loyalty programs based on trading volume and associated fees.
#
# Insights that could lead to negative growth typically arise from *ignoring* adverse fee patterns. For example, if the histogram reveals that a large portion of users are paying disproportionately high fees, it could lead to user dissatisfaction, churn, and a search for alternative platforms with more favorable fee structures. Conversely, if fees are consistently too low across the board, the platform might be missing opportunities for revenue generation, impacting its financial sustainability.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %%
account_volume = df.groupby('Account')['Size USD'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(15, 7))
sns.barplot(x='Account', y='Size USD', data=account_volume.head(10), hue='Account', palette='viridis', legend=False)
plt.title('Top 10 Accounts by Total Trading Volume (Size USD)')
plt.xlabel('Account ID')
plt.ylabel('Total Trading Volume (USD)')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# I chose a bar chart to visualize the 'Top 10 Accounts by Total Trading Volume (Size USD)' because it's excellent for comparing a quantitative value (trading volume) across discrete categorical entities (account IDs). The sorted bars clearly highlight the highest volume accounts, making it easy to identify the most active participants.

# %% [markdown]
# *   **Most Active Traders**: This chart will immediately show which specific accounts contribute the most to the platform's overall trading volume.
# *   **Volume Distribution**: It gives an idea of whether trading activity is concentrated among a few large accounts or more evenly distributed.
# *   **Key Players**: Identifying these accounts can be crucial for understanding market dynamics and for targeted business strategies.

# %% [markdown]
# Yes, insights from identifying the most active accounts can have a significant positive business impact:
#
# *   **Client Relationship Management**: The platform can provide premium services, dedicated support, or special incentives to high-volume accounts to foster loyalty and encourage continued activity.
# *   **Liquidity Provision**: Understanding where the most volume originates can help optimize liquidity provision strategies and ensure efficient market functioning.
# *   **Risk Monitoring**: High-volume accounts might require closer monitoring for potential market impact or concentration risk.
# *   **Product Development**: Insights from active traders could inform the development of features or tools that cater specifically to their needs, enhancing their trading experience.
#
# Insights that could lead to negative growth would arise from *ignoring* the implications of highly concentrated trading volume. For instance, if a few accounts dominate the volume, the platform becomes vulnerable to their behavior. If these key accounts reduce their activity or leave, it could severely impact overall trading volume and revenue. Neglecting to diversify the user base or relying too heavily on a small number of active traders could lead to instability.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Side', y='Closed PnL', data=df, palette='coolwarm')
plt.title('Distribution of Closed PnL by Trade Side (Buy/Sell)')
plt.xlabel('Trade Side')
plt.ylabel('Closed PnL')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_11431/3135073413.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Side', y='Closed PnL', data=df, palette='coolwarm')

# %% [markdown]
# I chose a box plot to visualize the 'Distribution of Closed PnL by Trade Side' because it effectively displays the distribution, central tendency (median), and spread of a continuous variable ('Closed PnL') across different categorical groups ('Side' - Buy/Sell). It also clearly shows outliers, which can represent exceptionally profitable or unprofitable trades for each side.

# %% [markdown]
# *   **Comparative Profitability**: The chart will allow us to compare the median and interquartile range of PnL for 'Buy' trades versus 'Sell' trades. This can reveal if one side of the market is generally more profitable than the other.
# *   **Risk Profile**: The spread of the boxes and the length of the whiskers can indicate the volatility or risk associated with each trade side. Larger spreads suggest higher variability in outcomes.
# *   **Outliers**: Extreme outliers will highlight individual trades that resulted in exceptionally high profits or losses for either 'Buy' or 'Sell' actions. These might warrant further investigation into specific market conditions or strategies.

# %% [markdown]
# Yes, these insights can significantly contribute to positive business impact:
#
# *   **Trading Strategy Development**: If one side ('Buy' or 'Sell') consistently shows higher average profitability or lower risk, traders can be advised or guided towards those strategies. The platform could develop features or educational content tailored to leverage these insights.
# *   **Risk Management**: Identifying which side of the market tends to have more extreme losses or higher variance can help in implementing specific risk controls, such as stricter margin requirements or automated safeguards for those types of trades.
# *   **Market Analysis**: Understanding which side is more successful can provide insights into overall market sentiment and direction during the analyzed period. For example, if 'Buy' trades are generally more profitable, it might suggest a bullish market.
#
# Insights that could lead to negative growth would stem from ignoring pronounced imbalances. For example, if one side of the trade consistently leads to significant losses for a large number of users, and the platform does not provide tools, education, or warnings to mitigate this, it could lead to user frustration, churn, and damage to the platform's reputation. Users might perceive the platform as unfair or biased if one trade direction is consistently disadvantageous without clear reasons or support.

# %% [markdown]
# #### Chart - 9

# %%
plt.figure(figsize=(12, 7))
sns.scatterplot(x='Size USD', y='Fee', data=df, alpha=0.6)
plt.title('Relationship between Transaction Fee and Size USD')
plt.xlabel('Size USD')
plt.ylabel('Fee')
plt.xscale('log') # Use log scale for better visualization if data is skewed
plt.yscale('log') # Use log scale for better visualization if data is skewed
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I chose a scatter plot to visualize the 'Relationship between Transaction Fee and Size USD'. This chart type is excellent for examining the correlation or pattern between two continuous numerical variables. It allows us to observe if fees tend to increase with the size of the transaction, and to identify any clusters or outliers that might indicate different fee structures or exceptional trades. Logarithmic scales are often useful when one or both variables have a wide range, helping to make patterns clearer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# *   **Correlation between Fee and Size USD**: The scatter plot will show if there is a positive, negative, or no correlation between the transaction size (in USD) and the fee. A positive correlation would imply that larger trades generally incur higher fees.
# *   **Fee Structure**: We might observe different tiers or structures in the fee system if the points form distinct lines or clusters. For example, some fees might be fixed, while others are a percentage of the transaction size.
# *   **Outliers**: Any points far from the main cluster could represent trades with unusually high or low fees for their size, warranting further investigation (e.g., promotional fees, special account types, or errors).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, these insights can have a significant positive business impact:
#
# *   **Fee Optimization**: Understanding the relationship between trade size and fees is crucial for optimizing the platform's fee model. If the current structure isn't competitive or clear, adjustments can be made to attract more users or maximize revenue.
# *   **Transparency and User Trust**: Clearly understanding and communicating the fee structure based on trade size can enhance user trust. Users are more likely to stay on a platform where costs are predictable and transparent.
# *   **Detecting Anomalies**: Any unusual fee-to-size ratios (outliers) could indicate system glitches, potential arbitrage opportunities, or even fraudulent activity that needs to be addressed immediately to prevent losses or maintain market integrity.
# *   **Product Development**: Insights might suggest new fee models for different user segments (e.g., volume-based discounts for large traders, simpler structures for small traders).
#
# Insights that could lead to negative growth would typically arise from *ignoring* adverse fee patterns. For instance, if the chart reveals that small trades are disproportionately burdened by high fees, it could deter new or small-scale investors, leading to reduced user acquisition. Conversely, if large trades are not adequately contributing to fee revenue, the platform might be missing out on significant income. Failing to adjust an inefficient or unfair fee structure can lead to user dissatisfaction, churn, and a decline in overall trading activity.

# %% [markdown]
# #### Chart - 10

# %%
coin_distribution = df['Coin'].value_counts().reset_index()
coin_distribution.columns = ['Coin', 'Count']

plt.figure(figsize=(15, 7))
sns.barplot(x='Coin', y='Count', data=coin_distribution.head(20), hue='Coin', palette='viridis', legend=False)
plt.title('Distribution of Top 20 Unique Coins (by Count)')
plt.xlabel('Coin')
plt.ylabel('Number of Trades')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I chose a bar chart to visualize the 'Distribution of Top 20 Unique Coins (by Count)' because it is highly effective for comparing the frequency or count of discrete categorical variables. It allows for easy identification of the most (and least) traded cryptocurrencies, providing a clear visual hierarchy of their activity on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# *   **Most Popular Coins**: The chart will clearly identify which coins are traded most frequently, indicating high user interest and liquidity for those assets.
# *   **Long-Tail Distribution**: It might show that a few coins dominate the trading activity, while many others are traded less often, suggesting a 'long-tail' distribution of assets.
# *   **Market Focus**: This insight can help understand the primary focus of traders on the platform and highlight potential niche markets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, these insights can significantly drive positive business impact:
#
# *   **Liquidity Management**: Knowing which coins are most popular helps the platform prioritize liquidity provision and market-making efforts for those assets, ensuring smooth trading and better prices for users.
# *   **Product Strategy**: The platform can focus on developing advanced features, analytics, or educational content for the most traded coins to enhance user experience and attract more traders.
# *   **Marketing and Promotions**: Marketing efforts can be tailored to highlight popular coins, attracting users interested in those specific assets. Conversely, promoting less popular coins might be a strategy to diversify trading activity.
# *   **Fee Structure Optimization**: The fee structure could be adjusted for different tiers of coins based on their trading volume, potentially offering lower fees for high-volume coins to encourage more trading.
#
# Insights that could lead to negative growth typically arise from *ignoring* market trends or imbalances. For example, if the platform fails to provide sufficient liquidity or competitive trading conditions for highly popular coins, users might migrate to other platforms. Conversely, if the platform over-invests in less popular coins that consistently show low trading activity, it could lead to inefficient resource allocation and missed opportunities in more vibrant markets.

# %% [markdown]
# #### Chart - 11

# %%
plt.figure(figsize=(14, 7))
sns.scatterplot(x='Start Position', y='Closed PnL', data=df, alpha=0.5)
plt.title('Relationship between Start Position and Closed PnL')
plt.xlabel('Start Position')
plt.ylabel('Closed PnL')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I chose a scatter plot to visualize the 'Relationship between Start Position and Closed PnL'. This chart type is excellent for examining the correlation or pattern between two continuous numerical variables. It allows us to observe if a larger starting position tends to correlate with different PnL outcomes (positive or negative), and to identify any clusters or outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# *   **Correlation between Start Position and PnL**: The scatter plot will show if there is a positive, negative, or no correlation between the initial position and the eventual profit or loss. For example, do larger start positions generally lead to larger profits or losses?
# *   **Risk Assessment**: It can help identify if traders with very high or very low starting positions tend to experience more extreme PnL outcomes.
# *   **Outliers**: Any points far from the main cluster could represent trades with unusually high profits or losses for a given starting position, warranting further investigation into specific trading strategies or market events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, these insights can have a significant positive business impact:
#
# *   **Trading Strategy Development**: Understanding how 'Start Position' relates to 'Closed PnL' can inform traders about optimal position sizing. The platform could provide guidance or tools to help users make better-informed decisions based on their initial capital.
# *   **Risk Management**: If certain starting position ranges are consistently associated with high losses, the platform can implement risk warnings, adjust margin requirements, or offer educational resources to help users manage their exposure. This protects users and the platform's stability.
# *   **Personalized Insights**: For advanced analytics, the platform could offer personalized insights to users, showing them how their 'Start Position' typically affects their 'Closed PnL', helping them refine their strategies.
#
# Insights that could lead to negative growth would typically arise from *ignoring* adverse patterns. For instance, if the chart reveals that traders with larger 'Start Positions' are disproportionately suffering large losses, and the platform fails to intervene with appropriate risk controls or educational content, it could lead to significant client dissatisfaction, withdrawal of funds, and reputational damage. This could deter high-value clients from using the platform.

# %% [markdown]
# #### Chart - 12

# %%
top_pnl_accounts = df.groupby('Account')['Closed PnL'].sum().sort_values(ascending=False).head(5).reset_index()

plt.figure(figsize=(12, 7))
sns.barplot(x='Account', y='Closed PnL', data=top_pnl_accounts, hue='Account', palette='magma', legend=False)
plt.title('Top 5 Accounts by Total Closed PnL')
plt.xlabel('Account ID')
plt.ylabel('Total Closed PnL')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I chose a bar chart to visualize the 'Top 5 Accounts by Total Closed PnL' because it is highly effective for comparing a quantitative variable (Total Closed PnL) across distinct categorical groups (Account IDs). The bars allow for easy comparison of profitability among the top accounts, and sorting them helps quickly identify the best performers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# *   **High-Value Accounts**: The chart clearly highlights the specific account IDs that have accumulated the highest total profits ('Closed PnL'), allowing for immediate identification of the top performers on the platform.
# *   **Profit Distribution**: It visually demonstrates the disparity in profitability among accounts, showing if profit generation is heavily concentrated in a few hands.
# *   **Performance Comparison**: Enables a quick comparison of the total PnL generated by each of the top accounts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Yes, identifying the top-performing accounts by PnL can have a significant positive business impact:
#
# *   **Client Relationship Management**: The platform can recognize and reward these high-value accounts, offering them premium services, lower fees, dedicated support, or exclusive features to enhance their loyalty and encourage continued high-volume, profitable trading.
# *   **Strategy Analysis & Education**: Analyzing the trading patterns, strategies, and asset choices of these successful accounts can provide valuable insights. This information can then be anonymized and used to develop educational content, trading tips, or even automated tools for other users, helping them improve their own profitability.
# *   **Product Development**: Features that support or enhance the strategies of these profitable traders could be prioritized, leading to a more robust and attractive trading environment for experienced users.
# *   **Marketing**: Highlighting the success stories (anonymously or with consent) can be a powerful marketing tool to attract new users who aspire to similar profitability.
#
# Insights that could lead to negative growth would typically arise from *ignoring* or *mismanaging* the implications of these findings. For example, if the platform does not adequately support or retain these top-performing accounts, they might migrate to competitors, leading to a significant loss of trading volume and PnL generation. Additionally, if the platform fails to scale its services or features to meet the demands of such high-performing traders, it could lead to dissatisfaction and churn. A purely profit-centric approach without considering risk management for all users could also backfire if it alienates less successful traders.

# %% [markdown]
# #### Chart - 13 - Correlation Heatmap

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.select_dtypes(include=['float64', 'int64', 'int32']).corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# I picked the Correlation Heatmap because it is an excellent tool for understanding the relationships between multiple numerical variables simultaneously. It provides a visual summary of the correlation matrix, allowing us to quickly identify which variables are strongly positively correlated, negatively correlated, or have little to no linear relationship. This is particularly insightful in a trading dataset where factors like 'Execution Price', 'Size USD', 'Fee', and 'Closed PnL' are likely to have interdependencies.

# %% [markdown]
# Answer Here.

# %% [markdown]
# *   **Identification of Strong Relationships**: We can quickly spot pairs of variables that move together (positive correlation) or in opposite directions (negative correlation). For example, we might see a strong positive correlation between 'Size Tokens' and 'Size USD', which is expected. More interestingly, we can look for correlations between trading parameters and 'Closed PnL' or 'Fee'.
# *   **Redundancy Detection**: High correlation between two independent variables might suggest redundancy, which could be important for feature selection in modeling.
# *   **Insight into Drivers**: If 'Execution Price' or 'Size USD' shows a strong correlation with 'Closed PnL', it indicates that these factors are significant drivers of profitability. Similarly, the correlation between 'Size USD' and 'Fee' will show how transaction fees scale with trade size.
# *   **Potential for Further Analysis**: Any unexpected strong or weak correlations can highlight areas for deeper investigation.

# %% [markdown]
# Yes, the insights from the Correlation Heatmap can have a significant positive business impact:
#
# *   **Strategy Optimization**: Understanding which factors are highly correlated with 'Closed PnL' can inform traders and the platform about potential strategies. For example, if a certain 'Execution Price' range consistently leads to higher PnL, this could be highlighted.
# *   **Fee Structure Analysis**: The correlation between 'Size USD' and 'Fee' can confirm if the current fee structure is linear, tiered, or has anomalies. This insight can help in optimizing fee models to maximize revenue while maintaining competitiveness and fairness.
# *   **Risk Management**: Identifying strong correlations between 'Start Position' and 'Closed PnL' (especially negative ones) can help in implementing better risk controls or warnings for certain trade sizes or position types.
# *   **Product Development**: Insights from correlations can guide the development of new features, analytical tools, or educational content. For instance, if 'Hour' of the day is correlated with PnL, time-based trading recommendations could be developed.
#
# Insights that could lead to negative growth would arise from *ignoring* critical correlations. For example, if there's a strong negative correlation between 'Execution Price' and 'Closed PnL' for certain coins, and the platform doesn't provide tools to mitigate this risk, users might incur consistent losses, leading to churn. Similarly, if the correlation suggests that the fee structure is unfairly penalizing small traders, this could deter new users and lead to negative publicity. Failing to address such issues can erode user trust and impact long-term growth.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# Based on the comprehensive Exploratory Data Analysis, several actionable insights emerge that can directly contribute to achieving business objectives related to optimizing trading performance, user experience, and platform profitability:
#
# **1. Optimize Resource Allocation based on Trading Volume Patterns:**
# *   **Insight**: Daily and hourly trading volume patterns (from Chart 1 and Chart 4) reveal peak activity periods. Some days/hours have significantly higher `Size USD` compared to others.
# *   **Suggestion**: The business should strategically allocate computing resources, customer support staff, and market-making efforts to align with these peak hours. This ensures system stability, reduces latency, improves user satisfaction, and capitalizes on high liquidity periods. Conversely, off-peak hours can be utilized for scheduled maintenance or system upgrades to minimize disruption.
#
# **2. Enhance Profitability through Coin-Specific Strategies:**
# *   **Insight**: The 'Average Closed PnL per Coin' (Chart 3) clearly indicates that some cryptocurrencies are consistently more profitable for traders than others. There are coins with high average positive PnL and others with significant average losses.
# *   **Suggestion**: The platform can:
#     *   **Promote Profitable Assets**: Highlight and provide more analytical tools/educational content for coins that show high average profitability to encourage informed trading.
#     *   **Risk Mitigation for Losing Assets**: For coins with consistently negative average PnL, the platform could issue warnings, suggest stricter risk management tools (like stop-losses), or review listing criteria if they consistently lead to user losses and dissatisfaction.
#
# **3. Refine Fee Structure for Competitiveness and Revenue Generation:**
# *   **Insight**: The 'Distribution of Transaction Fees' (Chart 6) and the 'Relationship between Transaction Fee and Size USD' (Chart 9) provide a clear picture of the current fee model. The correlation analysis (Chart 13) would further elucidate how fees relate to trade size and other factors.
# *   **Suggestion**: Analyze the current fee structure in detail. If large trades are not generating proportionate fees, consider tiered fee structures or volume-based discounts to incentivize larger transactions. If small trades are disproportionately burdened, it might deter new users; consider micro-transaction fee adjustments. The goal is to maximize revenue without alienating users, ensuring the fee model is perceived as fair and competitive.
#
# **4. Strategic Engagement with High-Value Accounts:**
# *   **Insight**: Identifying 'Top Accounts by Total Trading Volume' (Chart 7) and 'Top Accounts by Total Closed PnL' (Chart 12) pinpoints the most active and most profitable users on the platform. These accounts are critical drivers of liquidity and revenue.
# *   **Suggestion**: Develop a dedicated client relationship management (CRM) program for these high-value users. Offer premium services, personalized support, exclusive insights, or tailored features. Retaining these key players is vital for sustained business growth and market depth.
#
# **5. Improve Risk Management and User Education:**
# *   **Insight**: The 'Distribution of Closed PnL' (Chart 5), the 'Distribution of Closed PnL by Trade Side' (Chart 8), and the 'Relationship between Start Position and Closed PnL' (Chart 11) offer deep insights into user profitability and risk exposure. These charts highlight the frequency of losses, differences between buy/sell outcomes, and the impact of initial position size on PnL.
# *   **Suggestion**: Implement enhanced risk warnings and tools (e.g., advanced stop-loss/take-profit features, margin call alerts) particularly for scenarios identified as high-risk (e.g., specific trade directions or large start positions). Develop comprehensive educational resources on risk management and responsible trading practices, especially for newer or less profitable users.
#
# **6. Diversify Offerings and Optimize Market Presence:**
# *   **Insight**: The 'Distribution of Unique Coins' (Chart 10) shows which coins are most popular and which are less traded. This reflects market demand and user interest.
# *   **Suggestion**: While focusing on popular coins, strategically consider diversifying offerings or improving liquidity for less popular but potentially promising assets. Use insights from the most traded coins to understand market preferences and guide future asset listings or delistings. This can help attract a broader user base and expand market share.
#
# By systematically addressing these areas, the client can enhance platform efficiency, improve user retention, attract new traders, and ultimately drive sustainable business growth and profitability.

# %% [markdown]
# By systematically addressing these areas, the client can enhance platform efficiency, improve user retention, attract new traders, and ultimately drive sustainable business growth and profitability.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The comprehensive Exploratory Data Analysis of the historical trading data provided valuable insights into various aspects of the cryptocurrency exchange platform. We began by understanding the dataset's structure, identifying data types, and ensuring data quality by checking for missing values and duplicates. The data wrangling process involved crucial conversions of timestamp data and standardization of categorical features, making the dataset ready for in-depth analysis.
#
# Through a series of visualizations, we uncovered significant patterns and relationships:
#
# *   **Trading Volume Dynamics**: We observed distinct daily and hourly trading volume patterns, indicating periods of high and low activity that are crucial for resource allocation and strategic planning.
# *   **Coin Performance**: The analysis of average 'Closed PnL' per coin revealed varying profitability across different cryptocurrencies, highlighting opportunities for targeted promotions of profitable assets and risk mitigation for consistently losing ones.
# *   **Fee Structure Insights**: The distribution of transaction fees and its relationship with trade size provided a basis for optimizing the platform's fee model to ensure competitiveness and revenue generation.
# *   **User Behavior and Impact**: Identification of top accounts by trading volume and PnL underscored the importance of high-value clients and suggested strategies for client relationship management. The distribution of 'Closed PnL' and its correlation with 'Start Position' offered insights into user profitability and risk exposure, emphasizing the need for robust risk management tools and user education.
#
# In conclusion, this EDA project has successfully illuminated key operational, financial, and user-centric aspects of the trading platform. The derived insights provide a solid foundation for data-driven decision-making, enabling the business to enhance efficiency, improve user satisfaction, mitigate risks, and ultimately drive sustainable growth and profitability in the dynamic cryptocurrency market.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
